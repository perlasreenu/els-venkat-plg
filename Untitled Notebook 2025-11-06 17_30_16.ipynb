# %%
# read csv from the path 
path = "dbfs:/FileStore/datasets/journal_dummy_dataset.csv"
df = spark.read.csv(path, header=True, inferSchema=True)
# display the dataframe
display(df)

# %%
# %sh
wget https://kloud-mtl-kraft10-data.s3.us-east-1.amazonaws.com/spark/IO_Profiling.ipynb
