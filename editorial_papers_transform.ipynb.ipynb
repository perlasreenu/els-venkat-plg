# %%
# read file from s3 path and create dataframe
df = spark.read.csv("s3://venkat-els-databricks-training/editorial_papers_data (1).csv", header=True)

# %%
df.display()

# %%
# group the number of papers based on journal name
df.groupBy("journal_name").count().display()
